# %%
# Student Identity
LAST_NAME = "Rodelas"        
STUDENT_ID = "TUPM-25-0512" 

# Derive computational parameters
seed_digit = int(STUDENT_ID[-1])
id_checksum = sum(int(d) for d in STUDENT_ID if d.isdigit())
vector_dim = len(LAST_NAME)

# Encapsulate state into a Dictionary (Associative Map)
sys_config = {
    "operator": LAST_NAME,
    "auth_id": STUDENT_ID,
    "base_seed": seed_digit,
    "checksum": id_checksum,
    "vector_dim": vector_dim,
    "status": "INITIALIZED"
}

# Display system state
print("=== SYSTEM CONFIGURATION ===")
for key, value in sys_config.items():
    print(f"{key.upper()}: {value}")
# Out:
# Running cells with '.venv (3.14.2) (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ADMIN/COMPROG/Lab4_DataStructures_Rodelas/Lab4_DataStructures_Rodelas/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
